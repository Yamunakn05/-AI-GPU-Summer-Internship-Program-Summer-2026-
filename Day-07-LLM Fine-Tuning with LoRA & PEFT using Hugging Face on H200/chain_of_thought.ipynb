# %%
from groq import Groq

client = Groq(api_key="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")

prompt = """
A company has 125 employees.

40% work in Software Development.
25% work in Testing.
Remaining work in Support.

Think step by step and calculate carefully before giving the final answer.

1. Number of Software Developers
2. Number of Test Engineers
3. Number of Support Staff
"""

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": prompt}
    ],
    temperature=0
)

print(response.choices[0].message.content)
# Out:
# To find the number of employees in each department, we need to calculate the percentage of employees in each department.
#
# 1. Number of Software Developers:
# 40% of 125 employees = (40/100) * 125
# = 0.4 * 125
# = 50
#
# So, there are 50 Software Developers.
#
# 2. Number of Test Engineers:
# 25% of 125 employees = (25/100) * 125
# = 0.25 * 125
# = 31.25
#
# Since we can't have a fraction of a person, we round down to the nearest whole number is not necessary in this case as the question is about the number of employees which can be in decimal for calculation purposes but for the final count of employees, it will be rounded.
# So, there are 31 Test Engineers.
#
# 3. Number of Support Staff:
# To find the number of Support Staff, we need to subtract the number of Software Developers and Test Engineers from the total number of employees.
# Total employees = 125
# Software Developers = 50
# ...
