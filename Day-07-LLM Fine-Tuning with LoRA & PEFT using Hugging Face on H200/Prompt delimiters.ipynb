# %%
from groq import Groq

client = Groq(api_key="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")

prompt = """
### INSTRUCTION ###

Summarize the text in exactly 3 bullet points.

### INPUT TEXT ###

Artificial Intelligence is transforming
education by enabling personalized learning,
automated assessment systems, intelligent
tutoring platforms, and content generation.
It helps students learn at their own pace
while reducing administrative burden on
educators.

### OUTPUT ###
"""

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": prompt}
    ],
    temperature=0
)

print(response.choices[0].message.content)
# Out:
# * Artificial Intelligence is transforming education by enabling personalized learning and other innovative tools.
# * AI-powered systems can automate assessments, provide intelligent tutoring, and generate content to support student learning.
# * The integration of AI in education helps students learn at their own pace and reduces the administrative burden on educators.
